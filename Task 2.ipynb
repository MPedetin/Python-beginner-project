# %% [markdown]
# # TASK 2

# %% [markdown]
# ### A. The Campus Calculator

# %% [markdown]
# The calculator allowing the user to:

# %%
# add two number
def add(a,b) :
    return a + b

# %%
# to subtract two number
def subtract(a, b):
    return a - b

# %%
#to multiply two nunber
def multiply(a,b):
    return a*b

# %%
# to divide two number
def divide(a,b):
    if b==0:
        return "Error"
    else:
        return a/b

# %% [markdown]
# #### Menu driven calculator programm
# Main loop

# %%
choice = ""  # initialize choice before the loop i.e for python to know the variable already exist
while choice != "5":
    # Display menu
    print("Available Operations:")
    operations = ["1. Add", "2. Subtract", "3. Multiply", "4. Divide", "5. Quit"]
    for item in operations:
        print(item)

    # Ask user choice any operation
    choice = input("Please choose an operation (1–5): ")

    # Check if the user chose an operation
    if choice in ["1", "2", "3", "4"]:
        # We allow the Accept two numbers
        num1 = float(input("Enter the first number: "))
        num2 = float(input("Enter the second number: "))

        # Perform the chosen operation and since all operation as been defined
        if choice == "1":
            print("Result:", add(num1, num2))
            
        elif choice == "2":
            print("Result:", subtract(num1, num2))
            
        elif choice == "3":
            print("Result:", multiply(num1, num2))
            
        elif choice == "4":
            print("Result:", divide(num1, num2))

    # user chose to quit
    elif choice == "5":
        print("Exiting calculator. Goodbye!")

    # Invalid input
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Available Operations:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Quit
# Please choose an operation (1–5):  3
# Enter the first number:  6
# Enter the second number:  3
# Result: 18.0
# Available Operations:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Quit
# Please choose an operation (1–5):  5
# Exiting calculator. Goodbye!

# %% [markdown]
# ## B. The class Result Assistant

# %%
# To score student name and scores using a dictionary
students = { "Bella": [85, 95, 78],
    "Destiny": [75, 40, 80],
    "Goodness": [90, 88, 95],
    "Matthew": [60, 90, 95],
    "Samuel": [62, 79, 88],
    "Florence": [72, 99, 78],
    "Jabar": [72, 59, 35]}

# %%
# Function to calculate average
def calculate_average(scores):
    return sum(scores) / len(scores)

for student, scores in students.items():
    average = calculate_average(scores)
    print(f"{student} average score : {average:.1f}")
# Out:
# Bella average score : 86.0
# Destiny average score : 65.0
# Goodness average score : 91.0
# Matthew average score : 81.7
# Samuel average score : 76.3
# Florence average score : 83.0
# Jabar average score : 55.3

# %%
# Function to assign grade based on average
def assign_grade(average):
    if average >= 90:
        return "A"
    elif  average >= 80:
        return "B"
    elif average >= 70:
        return "C"
    elif average >= 60:
        return "D"
    else:
        return "F"

# %% [markdown]
# ### To display the final result

# %%
for student, scores in students.items():
    average = calculate_average(scores)
    grade = assign_grade(average)
    print(f"{student:<10}      average : {average:.1f}      grade : {grade}")
# Out:
# Bella           average : 86.0      grade : B
# Destiny         average : 65.0      grade : D
# Goodness        average : 91.0      grade : A
# Matthew         average : 81.7      grade : B
# Samuel          average : 76.3      grade : C
# Florence        average : 83.0      grade : B
# Jabar           average : 55.3      grade : F
